# %%
from fptas import *

# %% [markdown]
# ### Load data

# %%
prob = pd.read_csv(HOME + 'probabilities.csv')
prob['UTILITY'] = 1 / (prob.PROBABILITY)**(2)
prob.UTILITY += np.random.randn(len(prob.UTILITY)) / 10
prob['EU'] = prob.PROBABILITY * prob.UTILITY
prob = prob.sort_values('EU', ascending=False).reset_index(drop=True)
prob = prob[(prob.PROBABILITY > 0) & (prob.PROBABILITY < 1)].reset_index(drop=True)
prob.insert(0, 'NUMBER', range(len(prob)))
copy = prob.copy()

# %% [markdown]
# ### Default Settings

# %%
T = 0.9
K = 50
eps = 0.01

# %% [markdown]
# ### Get V*

# %%
v_star = get_vstar(prob=prob, T=T, K=K, eps=eps)
v_star
# Out:
# 101.3824118295122

# %% [markdown]
# ### Get delta, and round utilities

# %%
tprob = trim_probabilities(prob=prob, K=K, V_star=v_star, eps=eps)
tprob.head()
# Out:
# Delta is 0.02027648236590244
# Total error bounded in (1.013824118295122, 1.013824118295122)
#    NUMBER  SCHOOL_ID  PROBABILITY       UTILITY          EU            RU
# 0       0     460376         0.01  10000.027783  100.000278  10000.036679
# 1       1     484844         0.01   9999.945421   99.999454   9999.935297
# 2       2     110404         0.03   1111.026846   33.330805   1111.029575
# 3       3     166027         0.03   1110.994562   33.329837   1110.989022
# 4       4     190150         0.04    625.094988   25.003800    625.103675

# %% [markdown]
# # Estimating V

# %% [markdown]
# ### Risk averse

# %%
# %matplotlib notebook
run_value_function(prob=prob, 
                   T=T, 
                   K=K, 
                   eps=eps)
# Out:
# Running FPTAS for T=0.9, K=50
# V* is 101.32103672447961
# Delta is 0.02026420734489592
# Total error bounded in (1.013210367244796, 1.013210367244796)
# Added safety school 918.0. Current acceptance probability 0.9
# Added risky school 0.0. Current probability 0.901. Current V 101.2972374812024
# Added risky school 1.0. Current probability 0.9019900000000001. Current V 101.2972374812024
# Added risky school 2.0. Current probability 0.9049303000000001. Current V 101.29723748120239
# Added risky school 3.0. Current probability 0.907782391. Current V 101.2972374812024
# Added risky school 4.0. Current probability 0.91147109536. Current V 101.2972374812024
# Added risky school 5.0. Current probability 0.9150122515456001. Current V 101.2972374812024
# Added risky school 6.0. Current probability 0.918411761483776. Current V 101.2972374812024
# Added risky school 7.0. Current probability 0.9224911734095872. Current V 101.2972374812024
# Added risky school 8.0. Current probability 0.9263666147391079. Current V 101.2972374812024
# Added risky school 9.0. Current probability 0.9300482840021524. Current V 101.2972374812024
# Added risky school 10.0. Current probability 0.9342453869620233. Current V 101.2972374812024
# Added risky school 11.0. Current probability 0.9381906637443019. Current V 101.2972374812024
# Added risky school 12.0. Current probability 0.9418992239196439. Current V 101.2972374812024
# Added risky school 13.0. Current probability 0.9459662782452688. Current V 101.2972374812024
# Added risky school 14.0. Current probability 0.9497486387681. Current V 101.2972374812024
# Added risky school 15.0. Current probability 0.953266234054333. Current V 101.2972374812024
# Added risky school 16.0. Current probability 0.9565375976705297. Current V 101.2972374812024
# Added risky school 17.0. Current probability 0.9595799658335926. Current V 101.2972374812024
# Added risky school 18.0. Current probability 0.9624093682252411. Current V 101.2972374812024
# Added risky school 19.0. Current probability 0.9650407124494742. Current V 101.2972374812024
# Added risky school 20.0. Current probability 0.967487862578011. Current V 101.2972374812024
# Added risky school 21.0. Current probability 0.9697637121975503. Current V 101.2972374812024
# Added risky school 22.0. Current probability 0.9718802523437218. Current V 101.2972374812024
# Added risky school 23.0. Current probability 0.9741298321562241. Current V 101.29723748120239
# Added risky school 24.0. Current probability 0.9761994455837261. Current V 101.2972374812024
# Added risky school 25.0. Current probability 0.9783414954811908. Current V 101.29723748120239
# Added risky school 26.0. Current probability 0.9802907608878836. Current V 101.2972374812024
# Added risky school 27.0. Current probability 0.9820645924079741. Current V 101.2972374812024
# Added risky school 28.0. Current probability 0.9836787790912563. Current V 101.2972374812024
# Added risky school 29.0. Current probability 0.9851476889730433. Current V 101.2972374812024
# Added risky school 30.0. Current probability 0.986632920075739. Current V 101.2972374812024
# Added risky school 31.0. Current probability 0.9879696280681651. Current V 101.29723748120239
# Added risky school 32.0. Current probability 0.9891726652613486. Current V 101.2972374812024
# Added risky school 33.0. Current probability 0.9902553987352137. Current V 101.2972374812024
# Added risky school 34.0. Current probability 0.9913273048743402. Current V 101.29723748120242
# Added risky school 35.0. Current probability 0.9922813013381628. Current V 101.2972374812024
# Added risky school 36.0. Current probability 0.9931303581909648. Current V 101.2972374812024
# Added risky school 37.0. Current probability 0.9938860187899587. Current V 101.2972374812024
# Added risky school 38.0. Current probability 0.9945585567230633. Current V 101.2972374812024
# Added risky school 39.0. Current probability 0.9951571154835264. Current V 101.2972374812024
# Added risky school 40.0. Current probability 0.9956898327803384. Current V 101.2972374812024
# Added risky school 41.0. Current probability 0.9961639511745012. Current V 101.2972374812024
# Added risky school 42.0. Current probability 0.996624277033561. Current V 101.2972374812024
# Added risky school 43.0. Current probability 0.9970293637895338. Current V 101.2972374812024
# Added risky school 44.0. Current probability 0.9973858401347897. Current V 101.2972374812024
# Added risky school 45.0. Current probability 0.9976995393186149. Current V 101.2972374812024
# Added risky school 46.0. Current probability 0.9979755946003811. Current V 101.2972374812024
# Added risky school 47.0. Current probability 0.9982185232483354. Current V 101.2972374812024
# Added risky school 48.0. Current probability 0.9984323004585351. Current V 101.2972374812024
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Very risk averse

# %%
# %matplotlib notebook
run_value_function(prob=prob, 
                   T=0.99, 
                   K=50, 
                   eps=eps)
# Out:
# Running FPTAS for T=0.99, K=50
# V* is 101.25081775059495
# Delta is 0.02025016355011899
# Total error bounded in (1.0125081775059495, 1.0125081775059495)
# Added safety school 1090.0. Current acceptance probability 0.99
# Added risky school 0.0. Current probability 0.9901. Current V 101.2972374812024
# Added risky school 1.0. Current probability 0.9901989999999999. Current V 101.2972374812024
# Added risky school 2.0. Current probability 0.99049303. Current V 101.29723748120242
# Added risky school 3.0. Current probability 0.9907782391. Current V 101.2972374812024
# Added risky school 4.0. Current probability 0.991147109536. Current V 101.2972374812024
# Added risky school 5.0. Current probability 0.99150122515456. Current V 101.2972374812024
# Added risky school 6.0. Current probability 0.9918411761483776. Current V 101.2972374812024
# Added risky school 7.0. Current probability 0.9922491173409587. Current V 101.29723748120239
# Added risky school 8.0. Current probability 0.9926366614739108. Current V 101.2972374812024
# Added risky school 9.0. Current probability 0.9930048284002152. Current V 101.29723748120242
# Added risky school 10.0. Current probability 0.9934245386962023. Current V 101.2972374812024
# Added risky school 11.0. Current probability 0.9938190663744302. Current V 101.2972374812024
# Added risky school 12.0. Current probability 0.9941899223919644. Current V 101.2972374812024
# Added risky school 13.0. Current probability 0.9945966278245268. Current V 101.2972374812024
# Added risky school 14.0. Current probability 0.99497486387681. Current V 101.2972374812024
# Added risky school 15.0. Current probability 0.9953266234054333. Current V 101.2972374812024
# Added risky school 16.0. Current probability 0.995653759767053. Current V 101.2972374812024
# Added risky school 17.0. Current probability 0.9959579965833593. Current V 101.2972374812024
# Added risky school 18.0. Current probability 0.9962409368225241. Current V 101.2972374812024
# Added risky school 19.0. Current probability 0.9965040712449474. Current V 101.2972374812024
# Added risky school 20.0. Current probability 0.9967487862578011. Current V 101.2972374812024
# Added risky school 21.0. Current probability 0.996976371219755. Current V 101.2972374812024
# Added risky school 22.0. Current probability 0.9971880252343722. Current V 101.2972374812024
# Added risky school 23.0. Current probability 0.9974129832156224. Current V 101.2972374812024
# Added risky school 24.0. Current probability 0.9976199445583726. Current V 101.29723748120242
# Added risky school 25.0. Current probability 0.9978341495481191. Current V 101.29723748120239
# Added risky school 26.0. Current probability 0.9980290760887883. Current V 101.2972374812024
# Added risky school 27.0. Current probability 0.9982064592407974. Current V 101.2972374812024
# Added risky school 28.0. Current probability 0.9983678779091256. Current V 101.2972374812024
# Added risky school 29.0. Current probability 0.9985147688973043. Current V 101.2972374812024
# Added risky school 30.0. Current probability 0.9986632920075739. Current V 101.2972374812024
# Added risky school 31.0. Current probability 0.9987969628068165. Current V 101.2972374812024
# Added risky school 32.0. Current probability 0.9989172665261349. Current V 101.2972374812024
# Added risky school 33.0. Current probability 0.9990255398735214. Current V 101.2972374812024
# Added risky school 34.0. Current probability 0.999132730487434. Current V 101.2972374812024
# Added risky school 35.0. Current probability 0.9992281301338163. Current V 101.2972374812024
# Added risky school 36.0. Current probability 0.9993130358190965. Current V 101.29723748120239
# Added risky school 37.0. Current probability 0.9993886018789959. Current V 101.2972374812024
# Added risky school 38.0. Current probability 0.9994558556723063. Current V 101.2972374812024
# Added risky school 39.0. Current probability 0.9995157115483526. Current V 101.2972374812024
# Added risky school 40.0. Current probability 0.9995689832780339. Current V 101.29723748120242
# Added risky school 41.0. Current probability 0.9996163951174502. Current V 101.29723748120242
# Added risky school 42.0. Current probability 0.9996624277033561. Current V 101.2972374812024
# Added risky school 43.0. Current probability 0.9997029363789534. Current V 101.2972374812024
# Added risky school 44.0. Current probability 0.9997385840134789. Current V 101.2972374812024
# Added risky school 45.0. Current probability 0.9997699539318615. Current V 101.2972374812024
# Added risky school 46.0. Current probability 0.9997975594600381. Current V 101.2972374812024
# Added risky school 47.0. Current probability 0.9998218523248336. Current V 101.2972374812024
# Added risky school 48.0. Current probability 0.9998432300458535. Current V 101.2972374812024
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Risk loving

# %%
# %matplotlib notebook
run_value_function(prob=prob, 
                   T=0.40, 
                   K=10, 
                   eps=eps)
# Out:
# Running FPTAS for T=0.4, K=10
# V* is 102.56460167458319
# Delta is 0.10256460167458319
# Total error bounded in (1.025646016745832, 1.025646016745832)
# Added safety school 172.0. Current acceptance probability 0.4
# Added risky school 0.0. Current probability 0.406. Current V 101.2972374812024
# Added risky school 1.0. Current probability 0.4119400000000001. Current V 101.2972374812024
# Added risky school 2.0. Current probability 0.4295818000000001. Current V 101.2972374812024
# Added risky school 3.0. Current probability 0.44669434600000013. Current V 101.2972374812024
# Added risky school 4.0. Current probability 0.4688265721600001. Current V 101.2972374812024
# Added risky school 5.0. Current probability 0.49007350927360016. Current V 101.2972374812024
# Added risky school 6.0. Current probability 0.5104705689026562. Current V 101.29723748120242
# Added risky school 7.0. Current probability 0.5349470404575234. Current V 101.2972374812024
# Added risky school 8.0. Current probability 0.5581996884346472. Current V 101.2972374812024
# <img src="data:image/png;base64,..." width="640">
